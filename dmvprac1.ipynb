# %%
#pip install openpyxl

# %%
#pip install openpyxl --upgrade

# %%
#pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


#practical manual line number 22

# %%
df1=pd.read_csv('dmvprac1_sales_data_sample.csv', encoding='ISO-8859-1')
df2=pd.read_json('sales_json.json')
df3=pd.read_excel('sales_excel.xlsx')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df1.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df1.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df1.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
df1.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
df1.drop(columns=["ADDRESSLINE2", "STATE", "TERRITORY"], inplace=True)

# %%
df1.isnull().sum()
# Out:
# ORDERNUMBER          0
# QUANTITYORDERED      0
# PRICEEACH            0
# ORDERLINENUMBER      0
# SALES                0
# ORDERDATE            0
# STATUS               0
# QTR_ID               0
# MONTH_ID             0
# YEAR_ID              0
# PRODUCTLINE          0
# MSRP                 0
# PRODUCTCODE          0
# CUSTOMERNAME         0
# PHONE                0
# ADDRESSLINE1         0
# CITY                 0
# POSTALCODE          76
# COUNTRY              0
# CONTACTLASTNAME      0
# CONTACTFIRSTNAME     0
# DEALSIZE             0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# POSTALCODE          0
# COUNTRY             0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
df2.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER  \
# count    800.000000       800.000000  800.000000       800.000000
# mean   10261.280000        34.903750   79.199238         6.526250
# std       92.585307         9.316006   20.124248         4.291542
# min    10100.000000        11.000000   32.590000         1.000000
# 25%    10179.500000        27.000000   63.827500         3.000000
# 50%    10269.500000        34.000000   83.295000         6.000000
# 75%    10339.000000        43.000000  100.000000        10.000000
# max    10425.000000        85.000000  100.000000        18.000000
#
#               SALES      QTR_ID    MONTH_ID      YEAR_ID        MSRP
# count    800.000000  800.000000  800.000000   800.000000  800.000000
# mean    2973.176600    2.677500    7.011250  2003.845000   79.830000
# std     1324.415312    1.199079    3.636296     0.686706   22.475599
# min      482.130000    1.000000    1.000000  2003.000000   40.000000
# ...

# %%
df2.isnull().sum()
# Out:
# ORDERNUMBER           0
# QUANTITYORDERED       0
# PRICEEACH             0
# ORDERLINENUMBER       0
# SALES                 0
# ORDERDATE             0
# STATUS                0
# QTR_ID                0
# MONTH_ID              0
# YEAR_ID               0
# PRODUCTLINE           0
# MSRP                  0
# PRODUCTCODE           0
# CUSTOMERNAME          0
# PHONE                 0
# ADDRESSLINE1          0
# ADDRESSLINE2        722
# CITY                  0
# STATE               418
# POSTALCODE           11
# COUNTRY               0
# TERRITORY           309
# CONTACTLASTNAME       0
# CONTACTFIRSTNAME      0
# DEALSIZE              0
# dtype: int64

# %%
df2.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER  \
# count    800.000000       800.000000  800.000000       800.000000
# mean   10261.280000        34.903750   79.199238         6.526250
# std       92.585307         9.316006   20.124248         4.291542
# min    10100.000000        11.000000   32.590000         1.000000
# 25%    10179.500000        27.000000   63.827500         3.000000
# 50%    10269.500000        34.000000   83.295000         6.000000
# 75%    10339.000000        43.000000  100.000000        10.000000
# max    10425.000000        85.000000  100.000000        18.000000
#
#               SALES      QTR_ID    MONTH_ID      YEAR_ID        MSRP
# count    800.000000  800.000000  800.000000   800.000000  800.000000
# mean    2973.176600    2.677500    7.011250  2003.845000   79.830000
# std     1324.415312    1.199079    3.636296     0.686706   22.475599
# min      482.130000    1.000000    1.000000  2003.000000   40.000000
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 2023 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       800 non-null    int64
#  1   QUANTITYORDERED   800 non-null    int64
#  2   PRICEEACH         800 non-null    float64
#  3   ORDERLINENUMBER   800 non-null    int64
#  4   SALES             800 non-null    float64
#  5   ORDERDATE         800 non-null    object
#  6   STATUS            800 non-null    object
#  7   QTR_ID            800 non-null    int64
#  8   MONTH_ID          800 non-null    int64
#  9   YEAR_ID           800 non-null    int64
#  10  PRODUCTLINE       800 non-null    object
#  11  MSRP              800 non-null    int64
#  12  PRODUCTCODE       800 non-null    object
#  13  CUSTOMERNAME      800 non-null    object
#  14  PHONE             800 non-null    object
#  15  ADDRESSLINE1      800 non-null    object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 2023 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       800 non-null    int64
#  1   QUANTITYORDERED   800 non-null    int64
#  2   PRICEEACH         800 non-null    float64
#  3   ORDERLINENUMBER   800 non-null    int64
#  4   SALES             800 non-null    float64
#  5   ORDERDATE         800 non-null    object
#  6   STATUS            800 non-null    object
#  7   QTR_ID            800 non-null    int64
#  8   MONTH_ID          800 non-null    int64
#  9   YEAR_ID           800 non-null    int64
#  10  PRODUCTLINE       800 non-null    object
#  11  MSRP              800 non-null    int64
#  12  PRODUCTCODE       800 non-null    object
#  13  CUSTOMERNAME      800 non-null    object
#  14  PHONE             800 non-null    object
#  15  ADDRESSLINE1      800 non-null    object
# ...

# %%
df2.head()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2023        10416               18      75.06               13  1351.08
# 2024        10100               49      34.47                1  1689.03
# 2025        10110               48      34.47                5  1654.56
# 2026        10124               46      33.23                4  1528.58
# 2027        10149               26      38.98                9  1013.48
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2023  5/10/2005 0:00  Shipped       2         5     2005  ...
# 2024   1/6/2003 0:00  Shipped       1         1     2003  ...
# 2025  3/18/2003 0:00  Shipped       1         3     2003  ...
# 2026  5/21/2003 0:00  Shipped       2         5     2003  ...
# 2027  9/12/2003 0:00  Shipped       3         9     2003  ...
#
#                   ADDRESSLINE1  ADDRESSLINE2           CITY STATE POSTALCODE  \
# 2023    Strada Provinciale 124          None  Reggio Emilia  None      42100
# ...

# %%
df2.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
df2.drop(columns=["ADDRESSLINE2"], inplace=True)

# %%
df2.isnull().sum()
# Out:
# ORDERNUMBER           0
# QUANTITYORDERED       0
# PRICEEACH             0
# ORDERLINENUMBER       0
# SALES                 0
# ORDERDATE             0
# STATUS                0
# QTR_ID                0
# MONTH_ID              0
# YEAR_ID               0
# PRODUCTLINE           0
# MSRP                  0
# PRODUCTCODE           0
# CUSTOMERNAME          0
# PHONE                 0
# ADDRESSLINE1          0
# CITY                  0
# STATE               418
# POSTALCODE           11
# COUNTRY               0
# TERRITORY           309
# CONTACTLASTNAME       0
# CONTACTFIRSTNAME      0
# DEALSIZE              0
# dtype: int64

# %%
df2.drop(columns=["STATE", "TERRITORY"], inplace=True)

# %%
df2.isnull().sum()
# Out:
# ORDERNUMBER          0
# QUANTITYORDERED      0
# PRICEEACH            0
# ORDERLINENUMBER      0
# SALES                0
# ORDERDATE            0
# STATUS               0
# QTR_ID               0
# MONTH_ID             0
# YEAR_ID              0
# PRODUCTLINE          0
# MSRP                 0
# PRODUCTCODE          0
# CUSTOMERNAME         0
# PHONE                0
# ADDRESSLINE1         0
# CITY                 0
# POSTALCODE          11
# COUNTRY              0
# CONTACTLASTNAME      0
# CONTACTFIRSTNAME     0
# DEALSIZE             0
# dtype: int64

# %%
df2.dropna(inplace=True)

# %%
df2.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# POSTALCODE          0
# COUNTRY             0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
df3.describe()
# Out:
#        Unnamed: 0   ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER  \
# count    800.0000    800.000000       800.000000  800.000000        800.00000
# mean     399.5000  10257.332500        35.455000   91.714575          6.31750
# std      231.0844     92.197084         9.885476   15.877141          4.15069
# min        0.0000  10100.000000         6.000000   32.470000          1.00000
# 25%      199.7500  10179.500000        27.000000   93.340000          3.00000
# 50%      399.5000  10259.000000        35.000000  100.000000          6.00000
# 75%      599.2500  10332.000000        43.000000  100.000000          9.00000
# max      799.0000  10425.000000        97.000000  100.000000         18.00000
#
#               SALES      QTR_ID    MONTH_ID      YEAR_ID        MSRP
# count    800.000000  800.000000  800.000000   800.000000  800.000000
# mean    4438.189138    2.738750    7.143750  2003.800000  131.015000
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        800 non-null    int64
#  1   ORDERNUMBER       800 non-null    int64
#  2   QUANTITYORDERED   800 non-null    int64
#  3   PRICEEACH         800 non-null    float64
#  4   ORDERLINENUMBER   800 non-null    int64
#  5   SALES             800 non-null    float64
#  6   ORDERDATE         800 non-null    object
#  7   STATUS            800 non-null    object
#  8   QTR_ID            800 non-null    int64
#  9   MONTH_ID          800 non-null    int64
#  10  YEAR_ID           800 non-null    int64
#  11  PRODUCTLINE       800 non-null    object
#  12  MSRP              800 non-null    int64
#  13  PRODUCTCODE       800 non-null    object
#  14  CUSTOMERNAME      800 non-null    object
#  15  PHONE             800 non-null    object
# ...

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0            0
# ORDERNUMBER           0
# QUANTITYORDERED       0
# PRICEEACH             0
# ORDERLINENUMBER       0
# SALES                 0
# ORDERDATE             0
# STATUS                0
# QTR_ID                0
# MONTH_ID              0
# YEAR_ID               0
# PRODUCTLINE           0
# MSRP                  0
# PRODUCTCODE           0
# CUSTOMERNAME          0
# PHONE                 0
# ADDRESSLINE1          0
# ADDRESSLINE2        708
# CITY                  0
# STATE               412
# POSTALCODE           31
# COUNTRY               0
# TERRITORY           315
# CONTACTLASTNAME       0
# CONTACTFIRSTNAME      0
# DEALSIZE              0
# dtype: int64

# %%
df3.drop(columns=["ADDRESSLINE2", "STATE", "TERRITORY"], inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        800 non-null    int64
#  1   ORDERNUMBER       800 non-null    int64
#  2   QUANTITYORDERED   800 non-null    int64
#  3   PRICEEACH         800 non-null    float64
#  4   ORDERLINENUMBER   800 non-null    int64
#  5   SALES             800 non-null    float64
#  6   ORDERDATE         800 non-null    object
#  7   STATUS            800 non-null    object
#  8   QTR_ID            800 non-null    int64
#  9   MONTH_ID          800 non-null    int64
#  10  YEAR_ID           800 non-null    int64
#  11  PRODUCTLINE       800 non-null    object
#  12  MSRP              800 non-null    int64
#  13  PRODUCTCODE       800 non-null    object
#  14  CUSTOMERNAME      800 non-null    object
#  15  PHONE             800 non-null    object
# ...

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0           0
# ORDERNUMBER          0
# QUANTITYORDERED      0
# PRICEEACH            0
# ORDERLINENUMBER      0
# SALES                0
# ORDERDATE            0
# STATUS               0
# QTR_ID               0
# MONTH_ID             0
# YEAR_ID              0
# PRODUCTLINE          0
# MSRP                 0
# PRODUCTCODE          0
# CUSTOMERNAME         0
# PHONE                0
# ADDRESSLINE1         0
# CITY                 0
# POSTALCODE          31
# COUNTRY              0
# CONTACTLASTNAME      0
# CONTACTFIRSTNAME     0
# DEALSIZE             0
# dtype: int64

# %%
df3.dropna(inplace=True)

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0          0
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# POSTALCODE          0
# COUNTRY             0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
def clean_data(data):
    data.drop_duplicates(inplace=True)

# %%
clean_data(df1)
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# POSTALCODE          0
# COUNTRY             0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
clean_data(df2)
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# POSTALCODE          0
# COUNTRY             0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
clean_data(df3)
# Out:
# Unnamed: 0          0
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# POSTALCODE          0
# COUNTRY             0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
unified_data = pd.concat([df1, df2, df3], ignore_index=True)
unified_data.sample(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1140        10367               46     100.00                6  4808.38
# 3509        10415               42      57.61                3  2419.62
# 3129        10176               38      64.44                4  2448.72
# 4128        10342               55      65.45                1  3599.75
# 586         10278               29      90.86               10  2634.94
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 1140   1/12/2005 0:00  Resolved       1         1     2005  ...
# 3509    5/9/2005 0:00  Disputed       2         5     2005  ...
# 3129   11/6/2003 0:00   Shipped       4        11     2003  ...
# 4128  11/24/2004 0:00   Shipped       4        11     2004  ...
# 586     8/6/2004 0:00   Shipped       3         8     2004  ...
#
#                       CUSTOMERNAME           PHONE            ADDRESSLINE1  \
# ...

# %%
display(unified_data[["SALES","PRICEEACH"]].describe())

total_sales = unified_data['SALES'].sum()
print("Total Sales:", total_sales)

category_sales = unified_data.groupby('ORDERNUMBER')['SALES'].mean()
print("\nAverage Sales by Order Number:\n", category_sales)
# Out:
#               SALES    PRICEEACH
# count   4305.000000  4305.000000
# mean    3607.854627    84.308355
# std     1857.963238    19.790246
# min      482.130000    26.880000
# 25%     2249.050000    69.840000
# 50%     3223.440000    96.860000
# 75%     4534.600000   100.000000
# max    14082.800000   100.000000
# Total Sales: 15531814.169999998
#
# Average Sales by Order Number:
#  ORDERNUMBER
# 10100    3194.754286
# 10101    3042.868000
# 10102    3432.025000
# 10103    3518.852800
# 10104    3438.812727
#             ...
# 10421    3630.875000
# 10422    3083.400000
# 10423    1770.145000
# 10424    6246.369091
# 10425    3349.284762
# Name: SALES, Length: 298, dtype: float64

# %%
sns.boxplot(unified_data['SALES'])
plt.title('Sales Statistics (Box Plot)')
plt.xlabel('Sales Value')

plt.show()
